# %%
import numpy as np 
import matplotlib.pyplot as plt
fault_x = np.load("/h1/bhoon/20221229_pix2pix_lambda/scaled_refl_patch_OUT_lambda_1.npy")
fault_y = np.load("/h1/bhoon/20221229_pix2pix_lambda/FD_Y.npy")

# %%
def show_grid(data,r=4,c=4,jump=1,title='',save='',cmap='gray'):
    plt.figure(figsize=(c*2+1,r*2+1))
    i = 1
    for j in range(0,len(data),jump):
        dat = data[j]
        plt.subplot(r, c, i) 
        plt.imshow(dat, cmap=cmap)
        plt.axis('off')
        i+=1
        if i > r*c: break
    if title:
        plt.suptitle(title)
    if save:
        plt.savefig(save, bbox_inches='tight', pad_inches=0)
        plt.close()
    plt.show()

# %%
show_grid(fault_x[::135])
show_grid(fault_y[::135])

# %%
SPLIT = 5
fdata_idx  = np.arange(len(fault_x))
fvalid_idx = fdata_idx[::SPLIT]
ftrain_idx = np.delete(fdata_idx, fvalid_idx)

trainX = fault_x[ftrain_idx]
validX = fault_x[fvalid_idx]
trainY = fault_y[ftrain_idx]
validY = fault_y[fvalid_idx]

# %%
trainX.shape, validX.shape, trainY.shape, validY.shape
# Out:
# ((1920, 128, 128, 1), (480, 128, 128, 1), (1920, 128, 128), (480, 128, 128))

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

def unet(pretrained_weights = None,input_size = (None,None,1)):
    inputs = Input(input_size)

    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (inputs)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
#    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
#    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
#    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
#    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name='enc') (p4)
    c5 = Dropout(0.3) (c5)
#    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)
    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)
#    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
#    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.1) (c8)
#    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
#    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (3, 3), activation='sigmoid', padding='same') (c9)
    
    model = Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

earlystopper = EarlyStopping(patience=5, restore_best_weights=True)
model_checkpoint = ModelCheckpoint("/h1/bhoon/20221229_pix2pix_lambda/lambda_1.h5",
                                   monitor='val_loss',
                                   save_best_only=True,
                                   mode='min')

# %%
model = unet()
model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = 'accuracy')

# %%
# Model Train
result = model.fit(trainX, trainY,
                   epochs=200,
                   batch_size=32,
                   validation_data=(validX, validY),
                   callbacks=[earlystopper, model_checkpoint])
# Out:
# Epoch 1/200
# 60/60 [==============================] - 7s 57ms/step - loss: 0.1410 - accuracy: 0.9611 - val_loss: 0.0958 - val_accuracy: 0.9818
# Epoch 2/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0850 - accuracy: 0.9824 - val_loss: 0.0852 - val_accuracy: 0.9818
# Epoch 3/200
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0751 - accuracy: 0.9822 - val_loss: 0.0819 - val_accuracy: 0.9803
# Epoch 4/200
# 60/60 [==============================] - 2s 37ms/step - loss: 0.0589 - accuracy: 0.9823 - val_loss: 0.0503 - val_accuracy: 0.9827
# Epoch 5/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0471 - accuracy: 0.9833 - val_loss: 0.0456 - val_accuracy: 0.9833
# Epoch 6/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0407 - accuracy: 0.9847 - val_loss: 0.0398 - val_accuracy: 0.9854
# Epoch 7/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0374 - accuracy: 0.9857 - val_loss: 0.0368 - val_accuracy: 0.9861
# Epoch 8/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0349 - accuracy: 0.9864 - val_loss: 0.0358 - val_accuracy: 0.9863
# Epoch 9/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0329 - accuracy: 0.9870 - val_loss: 0.0330 - val_accuracy: 0.9873
# Epoch 10/200
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0311 - accuracy: 0.9876 - val_loss: 0.0322 - val_accuracy: 0.9875
# Epoch 11/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0296 - accuracy: 0.9881 - val_loss: 0.0318 - val_accuracy: 0.9878
# Epoch 12/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0287 - accuracy: 0.9884 - val_loss: 0.0305 - val_accuracy: 0.9882
# Epoch 13/200
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0271 - accuracy: 0.9890 - val_loss: 0.0299 - val_accuracy: 0.9887
# Epoch 14/200
# 60/60 [==============================] - 4s 68ms/step - loss: 0.0261 - accuracy: 0.9893 - val_loss: 0.0291 - val_accuracy: 0.9891
# Epoch 15/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0247 - accuracy: 0.9898 - val_loss: 0.0275 - val_accuracy: 0.9894
# Epoch 16/200
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0234 - accuracy: 0.9903 - val_loss: 0.0287 - val_accuracy: 0.9894
# Epoch 17/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0228 - accuracy: 0.9906 - val_loss: 0.0279 - val_accuracy: 0.9897
# Epoch 18/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0219 - accuracy: 0.9909 - val_loss: 0.0273 - val_accuracy: 0.9897
# Epoch 19/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0214 - accuracy: 0.9911 - val_loss: 0.0283 - val_accuracy: 0.9899
# Epoch 20/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0207 - accuracy: 0.9914 - val_loss: 0.0264 - val_accuracy: 0.9902
# Epoch 21/200
# 60/60 [==============================] - 2s 29ms/step - loss: 0.0201 - accuracy: 0.9916 - val_loss: 0.0273 - val_accuracy: 0.9901
# Epoch 22/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0188 - accuracy: 0.9921 - val_loss: 0.0267 - val_accuracy: 0.9902
# Epoch 23/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0181 - accuracy: 0.9924 - val_loss: 0.0282 - val_accuracy: 0.9900
# Epoch 24/200
# 60/60 [==============================] - 2s 39ms/step - loss: 0.0179 - accuracy: 0.9925 - val_loss: 0.0264 - val_accuracy: 0.9903
# Epoch 25/200
# 60/60 [==============================] - 2s 29ms/step - loss: 0.0171 - accuracy: 0.9928 - val_loss: 0.0272 - val_accuracy: 0.9901
# Epoch 26/200
# 60/60 [==============================] - 2s 29ms/step - loss: 0.0168 - accuracy: 0.9930 - val_loss: 0.0279 - val_accuracy: 0.9905
# Epoch 27/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0160 - accuracy: 0.9933 - val_loss: 0.0277 - val_accuracy: 0.9905
# Epoch 28/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0157 - accuracy: 0.9934 - val_loss: 0.0274 - val_accuracy: 0.9905
# Epoch 29/200
# 60/60 [==============================] - 3s 46ms/step - loss: 0.0152 - accuracy: 0.9937 - val_loss: 0.0258 - val_accuracy: 0.9907
# Epoch 30/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0149 - accuracy: 0.9937 - val_loss: 0.0265 - val_accuracy: 0.9907
# Epoch 31/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0144 - accuracy: 0.9939 - val_loss: 0.0275 - val_accuracy: 0.9906
# Epoch 32/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0138 - accuracy: 0.9942 - val_loss: 0.0276 - val_accuracy: 0.9906
# Epoch 33/200
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0138 - accuracy: 0.9942 - val_loss: 0.0270 - val_accuracy: 0.9909
# Epoch 34/200
# 60/60 [==============================] - 2s 30ms/step - loss: 0.0135 - accuracy: 0.9943 - val_loss: 0.0281 - val_accuracy: 0.9909

# %%
def standard_scaler(data):
    scaled = []
    for d in data:
        scaled.append((d - np.mean(d))/np.std(d))
    return np.array(scaled)

# %%
F3path = "/s1/bhoon/dataset/cyclegan_proj/real_f3_data/real_f3_data_raw.npy"
F3 = np.load(F3path).astype(np.float32)
F3 = np.swapaxes(F3,1,2)
F3 = standard_scaler(F3)
plt.figure(figsize=(30,20))
plt.imshow(F3[200],cmap='gray')

# %%
F3_pred = np.squeeze(model.predict(F3,batch_size=16))

# %%
save_path = '/h1/bhoon/20221229_pix2pix_lambda/result_lambda_1/'
try:
    os.mkdir(save_path)
except:
    pass

# %%
import cv2
from tqdm import tqdm

for idx in tqdm(range(len(F3_pred))):
    plt.figure(figsize=(30,20))
    plt.imshow(F3[idx],cmap='bwr',aspect='auto')
    plt.axis("off")
    plt.savefig('aaa.jpg', bbox_inches='tight', pad_inches=0)
    plt.close()

    plt.figure(figsize=(30,20))
    plt.imshow(F3_pred[idx],cmap='Greys',aspect='auto')
    plt.axis("off")
    plt.savefig('bbb.jpg', bbox_inches='tight', pad_inches=0)
    plt.close()

    aaa = cv2.imread('aaa.jpg')
    bbb = cv2.imread('bbb.jpg')
    ccc = np.where(bbb<255/2, 0, aaa)
    cv2.imwrite(save_path+"{}.jpg".format(str(idx).zfill(3)),ccc)
# Out:
# 100%|██████████| 601/601 [05:54<00:00,  1.70it/s]
